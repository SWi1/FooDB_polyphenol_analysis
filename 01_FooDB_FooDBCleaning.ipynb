# %% [markdown]
# # Matching FooDB to ASA24 Ingredient Descriptions
# ## Step 2: Clean FooDB's 'Content.csv'
#
# __Required Input Files__
#
#   - **Content.csv.bz2** - version 1, downloaded direct from foodb.ca
#   - **Food.csv** - version 1, downloaded direct from foodb.ca
#
#
# __Information__
# This script reformats and fills in missing food descriptions in FoodB's Content.csv. Specifically, this code:
#
#    1) Removes items derived from Pathbank (Lipid from Arabidopsis) and HMDB
#    2) Identifies missing common food descriptions
#    3) Add food descriptions from Food.csv
#        - This can lose additional information about preparation. However, this is the best descriptor possible given the information provided.
#    4) Identify which food descriptions are still missing and find closest description match.
#        - Output: Food_updated.csv
#    5) Update Content file to include food descriptions
#    6) Export updated Content file
#        - Output: Content_updated.csv
#
# __Outputs__
#
#   - **Content_updated.csv.bz2** - Food descriptions were added to all rows missing food descriptions in the original
#   - **Food_updated.csv** - Food 554 was added to the original Food.csv

# %%
#Load modules
import os
import pandas as pd
import numpy as np
import re
import bz2

# %%
#Ensure working directory is the project folder
mapping = os.getcwd()
mapping
# Out:
# '/Users/stephanie.wilson/Desktop/SYNC/Scripts/FooDB_FNDDS'

# %%
#Load data
Content = pd.read_csv('FooDB/Content.csv.bz2', compression='bz2', low_memory=False)
Food = pd.read_csv('FooDB/Food.csv')

# %% [markdown]
# ### 1) Remove rows from HMDB and Pathpank
#
# We are looking for compounds specifically within foods. So we will remove:
#   - endogenously produced compounds from humans (HMDB)
#   - lipids from arabidopsis (Pathbank)
#
# Rows meeting these criteria were all predicted and did NOT contain any content values.

# %%
#Remove data from Pathbank and HMDB
Content = Content[Content["orig_food_common_name"]!= 'Endogenous compounds from human (HMDB)']
Content = Content[Content['orig_food_common_name']!='Lipid from Arabidopsis (PathBank)']
Content.shape
#cuts numbers of rows down drastically
# Out:
# (1871970, 26)

# %% [markdown]
# ### 2) Identify which rows do not have food descriptions

# %%
#Pull out rows with missing common food descriptions
missing = Content[Content['orig_food_common_name'].isnull()]
print(missing.shape[0], ' rows are missing common food descriptions')
# Out:
# 971656  rows are missing common food descriptions

# %% [markdown]
# ### 3) Add food descriptions from Food.csv

# %%
# Rename in Food.csv to match column in Content
Food = Food.rename(columns = {'id':'food_id'})

# Filter in specific rows
Food = Food.filter(['food_id', 'name'], axis = 1)

# %%
# Merge missing data with food.csv
missing = pd.merge(missing, Food, on = 'food_id', how = 'left')
print(missing.shape[0], ' rows are missing common food descriptions')
# Out:
# 971656  rows are missing common food descriptions

# %%
# Replace orig_food_common_name (all missing) with matched name from Food.csv
missing['orig_food_common_name'] = missing['name']

# %%
# Drop the name column as we've transferred the names over to another column
missing.drop(columns=['name'], inplace=True)

# %% [markdown]
# ### 4) Identify which food descriptions are still missing and rectify.

# %%
# What didn't get a name?
still_missing = missing[missing['orig_food_common_name'].isnull()]
print(still_missing.shape[0], 'rows are still missing common food descriptions')
# Out:
# 1973 rows are still missing common food descriptions

# %%
# What food codes did not have a food description?
still_missing['food_id'].value_counts()
# food_id codes 554 and 16420 did not get a common name code
# Out:
# 554      1970
# 16420       3
# Name: food_id, dtype: int64

# %% [markdown]
# #### 4a) Resolve food_id 554

# %%
# What information do we have in FooDB Content on #554?
id554 = Content[(Content['food_id']==554)]
id554['orig_food_common_name'].value_counts()
# We can see that food_id 554 is equivalent to 'Owl, horned, flesh, raw (Alaska Native)'
# Out:
# Owl, horned, flesh, raw (Alaska Native)    11
# Name: orig_food_common_name, dtype: int64

# %%
Food.loc[(Food['food_id']==554)]
# Food 554 does not exist in Food.csv. Add this entry
# Out:
# Empty DataFrame
# Columns: [food_id, name]
# Index: []

# %%
# What information do we have in FooDB Content on #16420?
id16420 = Content[(Content['food_id']==16420)]
id16420
# We can see that food_id 554 is equivalent to 'Soy protein concentrate, aqueous washed'
# Out:
#               id  source_id source_type  food_id orig_food_id  \
# 1621939  1682964       2608    Compound    16420          NaN
# 1621940  1682965      11831    Compound    16420          NaN
# 1621941  1682966        698    Compound    16420          NaN
# 1621942  1682967       5583    Compound    16420          NaN
#
#                            orig_food_common_name orig_food_scientific_name  \
# 1621939  Soy protein concentrate, aqueous washed                       NaN
# 1621940                                      NaN                       NaN
# 1621941                                      NaN                       NaN
# 1621942                                      NaN                       NaN
#
#         orig_food_part orig_source_id orig_source_name  ...  citation_type  \
# 1621939            NaN            NaN              NaN  ...       DATABASE
# 1621940            NaN            NaN              NaN  ...       DATABASE
# 1621941            NaN            NaN              NaN  ...       DATABASE
# 1621942            NaN            NaN              NaN  ...       DATABASE
#
#          creator_id  updater_id               created_at  \
# 1621939         NaN         NaN  2019-08-03 15:05:06 UTC
# 1621940         NaN         NaN  2019-08-03 15:05:06 UTC
# 1621941         NaN         NaN  2019-08-03 15:05:06 UTC
# 1621942         NaN         NaN  2019-08-03 15:05:06 UTC
#
#                       updated_at orig_method orig_unit_expression  \
# 1621939  2019-08-03 15:05:06 UTC         NaN                  NaN
# 1621940  2019-08-03 15:05:06 UTC         NaN                  NaN
# 1621941  2019-08-03 15:05:06 UTC         NaN                  NaN
# 1621942  2019-08-03 15:05:06 UTC         NaN                  NaN
#
#          standard_content  preparation_type export
# 1621939             38.25               NaN      1
# 1621940             52.81               NaN      1
# 1621941              4.94               NaN      1
# 1621942             94.65               NaN      1
#
# [4 rows x 26 columns]

# %%
# Create Entry for 554, matches Food.csv col names
id554_entry = {'id':[554], 'name':['Owl, horned, flesh, raw (Alaska Native)']} 
id554_entry = pd.DataFrame(id554_entry)

# Reload Food.csv to make edits
Food_orig = pd.read_csv('FooDB/Food.csv')

# Add 554 to Foodb_food aka Food.csv
Food_orig = pd.concat([Food_orig, id554_entry], ignore_index = True)
Food_orig.to_csv('FooDB/Food_updated.csv', index = None, header = True)

# %% [markdown]
# #### 4b) Resolve food_id 16420

# %%
# Check if the code is a remnant from the database the compound was derived from and just didn't get converted.
id16420_orig = Content[(Content['orig_food_id']=='16420')]
id16420_orig
# Confirmed Code 16420 corresponds to FooDB's food codes 272 and 85
# Out:
#               id  source_id source_type  food_id orig_food_id  \
# 2945        2946          2    Nutrient      272        16420
# 12462      13270          3    Nutrient      272        16420
# 21441      23056          4    Nutrient      272        16420
# 29854      32237          5    Nutrient      272        16420
# 41612      45207         11    Nutrient      272        16420
# ...          ...        ...         ...      ...          ...
# 1819223  2268154      11682    Compound       85        16420
# 1819224  2268155       2942    Compound       85        16420
# 1819225  2268156      21595    Compound       85        16420
# 1819226  2268157      21595    Compound       85        16420
# 1819523  2268454         39    Nutrient       85        16420
#
#                                   orig_food_common_name  \
# 2945     Soy protein concentrate, produced by acid wash
# 12462    Soy protein concentrate, produced by acid wash
# 21441    Soy protein concentrate, produced by acid wash
# 29854    Soy protein concentrate, produced by acid wash
# 41612    Soy protein concentrate, produced by acid wash
# ...                                                 ...
# 1819223  Soy protein concentrate, produced by acid wash
# 1819224  Soy protein concentrate, produced by acid wash
# 1819225  Soy protein concentrate, produced by acid wash
# 1819226  Soy protein concentrate, produced by acid wash
# 1819523  Soy protein concentrate, produced by acid wash
#
#         orig_food_scientific_name orig_food_part orig_source_id  \
# 2945                          NaN            NaN            203
# 12462                         NaN            NaN            205
# 21441                         NaN            NaN            204
# 29854                         NaN            NaN            291
# 41612                         NaN            NaN            626
# ...                           ...            ...            ...
# 1819223                       NaN            NaN            613
# 1819224                       NaN            NaN            614
# 1819225                       NaN            NaN            645
# 1819226                       NaN            NaN            646
# 1819523                       NaN            NaN            NaN
#
#                            orig_source_name  ...  citation_type  creator_id  \
# 2945                                Protein  ...       DATABASE         NaN
# 12462           Carbohydrate, by difference  ...       DATABASE         NaN
# 21441                     Total lipid (fat)  ...       DATABASE         NaN
# 29854                  Fiber, total dietary  ...       DATABASE         NaN
# 41612                 16:1 undifferentiated  ...       DATABASE         NaN
# ...                                     ...  ...            ...         ...
# 1819223                                16:0  ...       DATABASE         NaN
# 1819224                                18:0  ...       DATABASE         NaN
# 1819225  Fatty acids, total monounsaturated  ...       DATABASE         NaN
# 1819226  Fatty acids, total polyunsaturated  ...       DATABASE         NaN
# 1819523                                 NaN  ...       DATABASE         NaN
#
#          updater_id               created_at               updated_at  \
# 2945            NaN  2014-11-05 13:42:42 UTC  2019-12-11 21:08:52 UTC
# 12462           NaN  2014-11-05 13:44:36 UTC  2019-12-11 21:08:52 UTC
# 21441           NaN  2014-11-05 13:46:24 UTC  2019-12-11 21:08:52 UTC
# 29854           NaN  2014-11-05 13:48:02 UTC  2019-12-11 21:08:52 UTC
# 41612           NaN  2014-11-05 13:50:20 UTC  2019-12-11 21:08:52 UTC
# ...             ...                      ...                      ...
# 1819223         NaN  2020-03-12 21:02:33 UTC  2020-03-12 21:02:33 UTC
# 1819224         NaN  2020-03-12 21:02:33 UTC  2020-03-12 21:02:33 UTC
# 1819225         NaN  2020-03-12 21:02:33 UTC  2020-03-12 21:02:33 UTC
# 1819226         NaN  2020-03-12 21:02:33 UTC  2020-03-12 21:02:33 UTC
# 1819523         NaN  2020-03-12 21:02:34 UTC  2020-03-12 21:02:34 UTC
#
#         orig_method orig_unit_expression  standard_content  preparation_type  \
# 2945            NaN                  NaN          58130.00             other
# 12462           NaN                  NaN          30910.00             other
# 21441           NaN                  NaN            460.00             other
# 29854           NaN                  NaN           5500.00             other
# 41612           NaN                  NaN              1.00             other
# ...             ...                  ...               ...               ...
# 1819223         NaN                  NaN             38.00             other
# 1819224         NaN                  NaN             13.00             other
# 1819225         NaN                  NaN             79.00             other
# 1819226         NaN                  NaN            201.00             other
# 1819523         NaN                  NaN              4.74             other
#
#         export
# 2945         0
# 12462        0
# 21441        0
# 29854        0
# 41612        0
# ...        ...
# 1819223      1
# 1819224      1
# 1819225      1
# 1819226      1
# 1819523      1
#
# [144 rows x 26 columns]

# %%
# What is the usage like for unique food codes 272 and 85?
id16420_orig['food_id'].value_counts()
# Out:
# 272    72
# 85     72
# Name: food_id, dtype: int64

# %%
# What are the food descriptors for 272 and 85
Food.loc[(Food['food_id']==272)|(Food['food_id']==85)]
# Will choose to classify id 16420 with food_id 272 'Other soy product' moving forward as it is more similar to FNDDS usage
# Out:
#      food_id               name
# 84        85           Soy bean
# 270      272  Other soy product

# %%
still_missing
# Next steps:
# Replace 554 name with 'Owl, horned, flesh, raw (Alaska Native)'
# Replace 16420 id with 272 and name with 'Soy protein concentrate, aqueous washed'
# Out:
#              id  source_id source_type  food_id orig_food_id  \
# 13762    760493      30233    Compound      554          NaN
# 14195    760926      30234    Compound      554          NaN
# 14628    761359          0    Compound      554          NaN
# 15061    761792      30235    Compound      554          NaN
# 15494    762225      30236    Compound      554          NaN
# ...         ...        ...         ...      ...          ...
# 921329  1669445      23346    Compound      554          NaN
# 921755  1669871       4663    Compound      554          NaN
# 934425  1682965      11831    Compound    16420          NaN
# 934426  1682966        698    Compound    16420          NaN
# 934427  1682967       5583    Compound    16420          NaN
#
#        orig_food_common_name orig_food_scientific_name orig_food_part  \
# 13762                    NaN                       NaN            NaN
# 14195                    NaN                       NaN            NaN
# 14628                    NaN                       NaN            NaN
# 15061                    NaN                       NaN            NaN
# 15494                    NaN                       NaN            NaN
# ...                      ...                       ...            ...
# 921329                   NaN                       NaN            NaN
# 921755                   NaN                       NaN            NaN
# 934425                   NaN                       NaN            NaN
# 934426                   NaN                       NaN            NaN
# 934427                   NaN                       NaN            NaN
#
#        orig_source_id orig_source_name  ...  citation_type  creator_id  \
# 13762             NaN              NaN  ...        UNKNOWN         NaN
# 14195             NaN              NaN  ...        UNKNOWN         NaN
# 14628             NaN              NaN  ...        UNKNOWN         NaN
# 15061             NaN              NaN  ...        UNKNOWN         NaN
# 15494             NaN              NaN  ...        UNKNOWN         NaN
# ...               ...              ...  ...            ...         ...
# 921329            NaN              NaN  ...        UNKNOWN         NaN
# 921755            NaN              NaN  ...        UNKNOWN         NaN
# 934425            NaN              NaN  ...       DATABASE         NaN
# 934426            NaN              NaN  ...       DATABASE         NaN
# 934427            NaN              NaN  ...       DATABASE         NaN
#
#         updater_id               created_at               updated_at  \
# 13762          NaN  2015-05-07 18:33:11 UTC  2015-05-07 18:33:11 UTC
# 14195          NaN  2015-05-07 18:33:17 UTC  2015-05-07 18:33:17 UTC
# 14628          NaN  2015-05-07 18:33:23 UTC  2015-05-07 18:33:23 UTC
# 15061          NaN  2015-05-07 18:33:29 UTC  2015-05-07 18:33:29 UTC
# 15494          NaN  2015-05-07 18:33:36 UTC  2015-05-07 18:33:36 UTC
# ...            ...                      ...                      ...
# 921329         NaN  2015-05-14 07:11:17 UTC  2015-05-14 07:11:17 UTC
# 921755         NaN  2015-05-14 07:11:30 UTC  2015-05-14 07:11:30 UTC
# 934425         NaN  2019-08-03 15:05:06 UTC  2019-08-03 15:05:06 UTC
# 934426         NaN  2019-08-03 15:05:06 UTC  2019-08-03 15:05:06 UTC
# 934427         NaN  2019-08-03 15:05:06 UTC  2019-08-03 15:05:06 UTC
#
#        orig_method orig_unit_expression  standard_content  preparation_type  \
# 13762          NaN                  NaN               NaN               NaN
# 14195          NaN                  NaN               NaN               NaN
# 14628          NaN                  NaN               NaN               NaN
# 15061          NaN                  NaN               NaN               NaN
# 15494          NaN                  NaN               NaN               NaN
# ...            ...                  ...               ...               ...
# 921329         NaN                  NaN               NaN               NaN
# 921755         NaN                  NaN               NaN               NaN
# 934425         NaN                  NaN             52.81               NaN
# 934426         NaN                  NaN              4.94               NaN
# 934427         NaN                  NaN             94.65               NaN
#
#        export
# 13762       1
# 14195       1
# 14628       1
# 15061       1
# 15494       1
# ...       ...
# 921329      1
# 921755      1
# 934425      1
# 934426      1
# 934427      1
#
# [1973 rows x 26 columns]

# %%
# Replace 554 name with 'Owl, horned, flesh, raw (Alaska Native)'
still_missing.loc[still_missing['food_id']==554, 'orig_food_common_name'] = 'Owl, horned, flesh, raw (Alaska Native)'
still_missing
# Out:
#              id  source_id source_type  food_id orig_food_id  \
# 13762    760493      30233    Compound      554          NaN
# 14195    760926      30234    Compound      554          NaN
# 14628    761359          0    Compound      554          NaN
# 15061    761792      30235    Compound      554          NaN
# 15494    762225      30236    Compound      554          NaN
# ...         ...        ...         ...      ...          ...
# 921329  1669445      23346    Compound      554          NaN
# 921755  1669871       4663    Compound      554          NaN
# 934425  1682965      11831    Compound    16420          NaN
# 934426  1682966        698    Compound    16420          NaN
# 934427  1682967       5583    Compound    16420          NaN
#
#                           orig_food_common_name orig_food_scientific_name  \
# 13762   Owl, horned, flesh, raw (Alaska Native)                       NaN
# 14195   Owl, horned, flesh, raw (Alaska Native)                       NaN
# 14628   Owl, horned, flesh, raw (Alaska Native)                       NaN
# 15061   Owl, horned, flesh, raw (Alaska Native)                       NaN
# 15494   Owl, horned, flesh, raw (Alaska Native)                       NaN
# ...                                         ...                       ...
# 921329  Owl, horned, flesh, raw (Alaska Native)                       NaN
# 921755  Owl, horned, flesh, raw (Alaska Native)                       NaN
# 934425                                      NaN                       NaN
# 934426                                      NaN                       NaN
# 934427                                      NaN                       NaN
#
#        orig_food_part orig_source_id orig_source_name  ...  citation_type  \
# 13762             NaN            NaN              NaN  ...        UNKNOWN
# 14195             NaN            NaN              NaN  ...        UNKNOWN
# 14628             NaN            NaN              NaN  ...        UNKNOWN
# 15061             NaN            NaN              NaN  ...        UNKNOWN
# 15494             NaN            NaN              NaN  ...        UNKNOWN
# ...               ...            ...              ...  ...            ...
# 921329            NaN            NaN              NaN  ...        UNKNOWN
# 921755            NaN            NaN              NaN  ...        UNKNOWN
# 934425            NaN            NaN              NaN  ...       DATABASE
# 934426            NaN            NaN              NaN  ...       DATABASE
# 934427            NaN            NaN              NaN  ...       DATABASE
#
#         creator_id  updater_id               created_at  \
# 13762          NaN         NaN  2015-05-07 18:33:11 UTC
# 14195          NaN         NaN  2015-05-07 18:33:17 UTC
# 14628          NaN         NaN  2015-05-07 18:33:23 UTC
# 15061          NaN         NaN  2015-05-07 18:33:29 UTC
# 15494          NaN         NaN  2015-05-07 18:33:36 UTC
# ...            ...         ...                      ...
# 921329         NaN         NaN  2015-05-14 07:11:17 UTC
# 921755         NaN         NaN  2015-05-14 07:11:30 UTC
# 934425         NaN         NaN  2019-08-03 15:05:06 UTC
# 934426         NaN         NaN  2019-08-03 15:05:06 UTC
# 934427         NaN         NaN  2019-08-03 15:05:06 UTC
#
#                      updated_at orig_method orig_unit_expression  \
# 13762   2015-05-07 18:33:11 UTC         NaN                  NaN
# 14195   2015-05-07 18:33:17 UTC         NaN                  NaN
# 14628   2015-05-07 18:33:23 UTC         NaN                  NaN
# 15061   2015-05-07 18:33:29 UTC         NaN                  NaN
# 15494   2015-05-07 18:33:36 UTC         NaN                  NaN
# ...                         ...         ...                  ...
# 921329  2015-05-14 07:11:17 UTC         NaN                  NaN
# 921755  2015-05-14 07:11:30 UTC         NaN                  NaN
# 934425  2019-08-03 15:05:06 UTC         NaN                  NaN
# 934426  2019-08-03 15:05:06 UTC         NaN                  NaN
# 934427  2019-08-03 15:05:06 UTC         NaN                  NaN
#
#         standard_content  preparation_type export
# 13762                NaN               NaN      1
# 14195                NaN               NaN      1
# 14628                NaN               NaN      1
# 15061                NaN               NaN      1
# 15494                NaN               NaN      1
# ...                  ...               ...    ...
# 921329               NaN               NaN      1
# 921755               NaN               NaN      1
# 934425             52.81               NaN      1
# 934426              4.94               NaN      1
# 934427             94.65               NaN      1
#
# [1973 rows x 26 columns]

# %%
# Replace 16420 name description with 'Soy protein concentrate, aqueous washed'
still_missing.loc[still_missing['food_id']==16420, 'orig_food_common_name'] = 'Soy protein concentrate, aqueous washed'
still_missing
# Out:
#              id  source_id source_type  food_id orig_food_id  \
# 13762    760493      30233    Compound      554          NaN
# 14195    760926      30234    Compound      554          NaN
# 14628    761359          0    Compound      554          NaN
# 15061    761792      30235    Compound      554          NaN
# 15494    762225      30236    Compound      554          NaN
# ...         ...        ...         ...      ...          ...
# 921329  1669445      23346    Compound      554          NaN
# 921755  1669871       4663    Compound      554          NaN
# 934425  1682965      11831    Compound    16420          NaN
# 934426  1682966        698    Compound    16420          NaN
# 934427  1682967       5583    Compound    16420          NaN
#
#                           orig_food_common_name orig_food_scientific_name  \
# 13762   Owl, horned, flesh, raw (Alaska Native)                       NaN
# 14195   Owl, horned, flesh, raw (Alaska Native)                       NaN
# 14628   Owl, horned, flesh, raw (Alaska Native)                       NaN
# 15061   Owl, horned, flesh, raw (Alaska Native)                       NaN
# 15494   Owl, horned, flesh, raw (Alaska Native)                       NaN
# ...                                         ...                       ...
# 921329  Owl, horned, flesh, raw (Alaska Native)                       NaN
# 921755  Owl, horned, flesh, raw (Alaska Native)                       NaN
# 934425  Soy protein concentrate, aqueous washed                       NaN
# 934426  Soy protein concentrate, aqueous washed                       NaN
# 934427  Soy protein concentrate, aqueous washed                       NaN
#
#        orig_food_part orig_source_id orig_source_name  ...  citation_type  \
# 13762             NaN            NaN              NaN  ...        UNKNOWN
# 14195             NaN            NaN              NaN  ...        UNKNOWN
# 14628             NaN            NaN              NaN  ...        UNKNOWN
# 15061             NaN            NaN              NaN  ...        UNKNOWN
# 15494             NaN            NaN              NaN  ...        UNKNOWN
# ...               ...            ...              ...  ...            ...
# 921329            NaN            NaN              NaN  ...        UNKNOWN
# 921755            NaN            NaN              NaN  ...        UNKNOWN
# 934425            NaN            NaN              NaN  ...       DATABASE
# 934426            NaN            NaN              NaN  ...       DATABASE
# 934427            NaN            NaN              NaN  ...       DATABASE
#
#         creator_id  updater_id               created_at  \
# 13762          NaN         NaN  2015-05-07 18:33:11 UTC
# 14195          NaN         NaN  2015-05-07 18:33:17 UTC
# 14628          NaN         NaN  2015-05-07 18:33:23 UTC
# 15061          NaN         NaN  2015-05-07 18:33:29 UTC
# 15494          NaN         NaN  2015-05-07 18:33:36 UTC
# ...            ...         ...                      ...
# 921329         NaN         NaN  2015-05-14 07:11:17 UTC
# 921755         NaN         NaN  2015-05-14 07:11:30 UTC
# 934425         NaN         NaN  2019-08-03 15:05:06 UTC
# 934426         NaN         NaN  2019-08-03 15:05:06 UTC
# 934427         NaN         NaN  2019-08-03 15:05:06 UTC
#
#                      updated_at orig_method orig_unit_expression  \
# 13762   2015-05-07 18:33:11 UTC         NaN                  NaN
# 14195   2015-05-07 18:33:17 UTC         NaN                  NaN
# 14628   2015-05-07 18:33:23 UTC         NaN                  NaN
# 15061   2015-05-07 18:33:29 UTC         NaN                  NaN
# 15494   2015-05-07 18:33:36 UTC         NaN                  NaN
# ...                         ...         ...                  ...
# 921329  2015-05-14 07:11:17 UTC         NaN                  NaN
# 921755  2015-05-14 07:11:30 UTC         NaN                  NaN
# 934425  2019-08-03 15:05:06 UTC         NaN                  NaN
# 934426  2019-08-03 15:05:06 UTC         NaN                  NaN
# 934427  2019-08-03 15:05:06 UTC         NaN                  NaN
#
#         standard_content  preparation_type export
# 13762                NaN               NaN      1
# 14195                NaN               NaN      1
# 14628                NaN               NaN      1
# 15061                NaN               NaN      1
# 15494                NaN               NaN      1
# ...                  ...               ...    ...
# 921329               NaN               NaN      1
# 921755               NaN               NaN      1
# 934425             52.81               NaN      1
# 934426              4.94               NaN      1
# 934427             94.65               NaN      1
#
# [1973 rows x 26 columns]

# %%
# Replace 16420 with 272 
still_missing['food_id'].replace(to_replace = 16420, value = 272, inplace=True)
still_missing
# Out:
# /var/folders/97/xy0dx75x50j0hqykjglgn13x4zqr1q/T/ipykernel_10623/3489310927.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   still_missing['food_id'].replace(to_replace = 16420, value = 272, inplace=True)
#              id  source_id source_type  food_id orig_food_id  \
# 13762    760493      30233    Compound      554          NaN
# 14195    760926      30234    Compound      554          NaN
# 14628    761359          0    Compound      554          NaN
# 15061    761792      30235    Compound      554          NaN
# 15494    762225      30236    Compound      554          NaN
# ...         ...        ...         ...      ...          ...
# 921329  1669445      23346    Compound      554          NaN
# 921755  1669871       4663    Compound      554          NaN
# 934425  1682965      11831    Compound      272          NaN
# 934426  1682966        698    Compound      272          NaN
# 934427  1682967       5583    Compound      272          NaN
#
#                           orig_food_common_name orig_food_scientific_name  \
# 13762   Owl, horned, flesh, raw (Alaska Native)                       NaN
# 14195   Owl, horned, flesh, raw (Alaska Native)                       NaN
# 14628   Owl, horned, flesh, raw (Alaska Native)                       NaN
# 15061   Owl, horned, flesh, raw (Alaska Native)                       NaN
# 15494   Owl, horned, flesh, raw (Alaska Native)                       NaN
# ...                                         ...                       ...
# 921329  Owl, horned, flesh, raw (Alaska Native)                       NaN
# 921755  Owl, horned, flesh, raw (Alaska Native)                       NaN
# 934425  Soy protein concentrate, aqueous washed                       NaN
# 934426  Soy protein concentrate, aqueous washed                       NaN
# 934427  Soy protein concentrate, aqueous washed                       NaN
#
#        orig_food_part orig_source_id orig_source_name  ...  citation_type  \
# 13762             NaN            NaN              NaN  ...        UNKNOWN
# 14195             NaN            NaN              NaN  ...        UNKNOWN
# 14628             NaN            NaN              NaN  ...        UNKNOWN
# 15061             NaN            NaN              NaN  ...        UNKNOWN
# 15494             NaN            NaN              NaN  ...        UNKNOWN
# ...               ...            ...              ...  ...            ...
# 921329            NaN            NaN              NaN  ...        UNKNOWN
# 921755            NaN            NaN              NaN  ...        UNKNOWN
# 934425            NaN            NaN              NaN  ...       DATABASE
# 934426            NaN            NaN              NaN  ...       DATABASE
# 934427            NaN            NaN              NaN  ...       DATABASE
#
#         creator_id  updater_id               created_at  \
# 13762          NaN         NaN  2015-05-07 18:33:11 UTC
# 14195          NaN         NaN  2015-05-07 18:33:17 UTC
# 14628          NaN         NaN  2015-05-07 18:33:23 UTC
# 15061          NaN         NaN  2015-05-07 18:33:29 UTC
# 15494          NaN         NaN  2015-05-07 18:33:36 UTC
# ...            ...         ...                      ...
# 921329         NaN         NaN  2015-05-14 07:11:17 UTC
# 921755         NaN         NaN  2015-05-14 07:11:30 UTC
# 934425         NaN         NaN  2019-08-03 15:05:06 UTC
# 934426         NaN         NaN  2019-08-03 15:05:06 UTC
# 934427         NaN         NaN  2019-08-03 15:05:06 UTC
#
#                      updated_at orig_method orig_unit_expression  \
# 13762   2015-05-07 18:33:11 UTC         NaN                  NaN
# 14195   2015-05-07 18:33:17 UTC         NaN                  NaN
# 14628   2015-05-07 18:33:23 UTC         NaN                  NaN
# 15061   2015-05-07 18:33:29 UTC         NaN                  NaN
# 15494   2015-05-07 18:33:36 UTC         NaN                  NaN
# ...                         ...         ...                  ...
# 921329  2015-05-14 07:11:17 UTC         NaN                  NaN
# 921755  2015-05-14 07:11:30 UTC         NaN                  NaN
# 934425  2019-08-03 15:05:06 UTC         NaN                  NaN
# 934426  2019-08-03 15:05:06 UTC         NaN                  NaN
# 934427  2019-08-03 15:05:06 UTC         NaN                  NaN
#
#         standard_content  preparation_type export
# 13762                NaN               NaN      1
# 14195                NaN               NaN      1
# 14628                NaN               NaN      1
# 15061                NaN               NaN      1
# 15494                NaN               NaN      1
# ...                  ...               ...    ...
# 921329               NaN               NaN      1
# 921755               NaN               NaN      1
# 934425             52.81               NaN      1
# 934426              4.94               NaN      1
# 934427             94.65               NaN      1
#
# [1973 rows x 26 columns]

# %% [markdown]
# ### 5) Update Content file
#
# Recall: missing was updated to include food descriptions from Food.csv. Anything that didn't have a description went on to still_missing for identification.
#
# We will now drop those rows with a missing description and add still_missing which has the added descriptions.

# %%
# drop rows wih missing description
missing = missing.dropna(subset=['orig_food_common_name'])

# %%
# add still missing (updated now with names!) to missing_
missing_updated = pd.concat([missing, still_missing], ignore_index = True)

# %%
# Confirm there are now no missing food descriptions
missing_check = missing_updated[missing_updated['orig_food_common_name'].isnull()]
print(missing_check.shape[0], ' rows are missing common food descriptions')
# Out:
# 0  rows are missing common food descriptions

# %% [markdown]
# We will repeat the above process to fill in the Content file.

# %%
# drop rows wih missing description
Content = Content.dropna(subset=['orig_food_common_name'])

# %%
# add missing_updated to Content
Content_updated = pd.concat([Content, missing_updated], ignore_index = True)

# %%
# Confirm there are now no missing food descriptions
Content_check = Content_updated[Content_updated['orig_food_common_name'].isnull()]
print(Content_check.shape[0], ' rows are missing common food descriptions')
# Out:
# 0  rows are missing common food descriptions

# %%
# Establish a unique number for each group of food names, starting from 1
Content_updated['food_V2_ID'] = pd.factorize(Content_updated['orig_food_common_name'])[0] + 1

# %% [markdown]
# ### 6) Export Updated Content File
#
# Export the content file now updated and complete with food descriptions for every entry.

# %%
Content_updated.to_csv('FooDB/Content_updated.csv.bz2', index = None, header = True)

# %%
#Matches the original dimensions + 1 for the duplicate ID column
Content_updated.shape
# Out:
# (1871970, 27)
